# %% [markdown]
# This notebook will test how serial generatin time will affect estiamtion of Rt
# Hong Qin

# %%
install.packages('R0', lib = '/content')
#library('R0')
library("R0", lib.loc="/content")
# Out:
# Loading required package: MASS

# %%
data(Germany.1918)
plot(Germany.1918)
# Out:
# plot without title

# %%
mGT <- generation.time("gamma", c(3,1.5))
SB <- est.R0.SB(Germany.1918, mGT, begin=1, end=100)
plot(SB)
# Out:
# Plot with title “Reproduction number ( Sequential Bayesian )”

# %%
mGT <- generation.time("gamma", c(3,1.5))
TD <- est.R0.TD(Germany.1918, mGT, begin=1, end=100)
# Out:
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Simulations may take several minutes.”
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Using initial incidence as initial number of cases.”

# %%
plot(TD)
# Out:
# Plot with title “Reproduction number ( Time-Dependent )”

# %%
mGT <- generation.time("gamma", c(5,1.5))
TD <- est.R0.TD(Germany.1918, mGT, begin=1, end=100)
plot(TD)
# Out:
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Simulations may take several minutes.”
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Using initial incidence as initial number of cases.”
# Plot with title “Reproduction number ( Time-Dependent )”

# %%
mGT <- generation.time("gamma", c(2,1.5)) #it seems short generation time lead to more noisy fit
TD <- est.R0.TD(Germany.1918, mGT, begin=1, end=100)
plot(TD)
# Out:
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Simulations may take several minutes.”
# Warning message in est.R0.TD(Germany.1918, mGT, begin = 1, end = 100):
# “Using initial incidence as initial number of cases.”
# Plot with title “Reproduction number ( Time-Dependent )”
